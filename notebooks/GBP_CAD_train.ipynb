# %% [markdown]
# # Построение модели

# %% [markdown]
# ## Выбор инструмента для анализа
#
# Попробуем построить модель для торговли GBP_CAD.
#
#
# Нефть, природный газ, никель, медь, цинк, уран, битум, пшеница, чечевица, рапс, женьшень, латук, огурец, кукуруза, яблоки, клубника, лес
#
# Канада — крупнейший торговый партнёр США

# %%
import re
import pandas as pd
from learning.features import get_features
import matplotlib.pylab as plt

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
from finam_data.models import *
from finam_data.utils import collect_instrument_candles
from finam.export import Exporter, LookupComparator

# %%
exporter = Exporter()

# %% [markdown]
# ## Все доступные курсы CAD

# %%
cad_available_currencies = exporter.lookup(
    name='Cad',
    market=ExtendedMarket.WORLD_CURRENCIES,
    name_comparator=LookupComparator.CONTAINS,
).name.to_list()
for name in cad_available_currencies:
    print (name)
    i, _ = Instrument.objects.get_or_create(
        name=name,
        market=ExtendedMarket.WORLD_CURRENCIES,
    )
    collect_instrument_candles(i)
# Out:
# Aud/Cad
# Usd/Cad
# Eur/Cad
# Gbp/Cad
# Cad/Chf
# Cad/Jpy
# Cad/Usd
# Nzd/Cad

# %% [markdown]
# ## Товары

# %%
cad_available_commodities = exporter.lookup(
    name='Цинк|Никель|Медь|Уран|Битум|Пшеница|Кукуруза',
    market=ExtendedMarket.COMMODITIES,
    name_comparator=LookupComparator.CONTAINS,
).name.to_list()
cad_available_commodities += exporter.lookup(
    name='Brent',
    market=ExtendedMarket.COMMODITIES,
    name_comparator=LookupComparator.EQUALS,
).name.to_list()
for name in cad_available_commodities:
    print (name)
    i, _ = Instrument.objects.get_or_create(
        name=name,
        market=ExtendedMarket.COMMODITIES,
    )
    collect_instrument_candles(i)
# Out:
# Никель
# Медь
# Цинк
# Пшеница
# Brent

# %% [markdown]
# ## Скомпилируем датафрейм

# %%
feature_regexp = '^({})_close_finam$'.format('|'.join(cad_available_currencies + cad_available_commodities))
features = get_features(lambda x: re.match(feature_regexp, x))

# %%
df = None

for f in features:
    print (f.name)
    tmp_df = f.load()
    df = tmp_df if df is None else pd.concat([df, tmp_df], axis=1, ignore_index=False)
# Out:
# Gbp/Cad_close_finam
# Aud/Cad_close_finam
# Usd/Cad_close_finam
# Eur/Cad_close_finam
# Cad/Chf_close_finam
# Cad/Jpy_close_finam
# Cad/Usd_close_finam
# Nzd/Cad_close_finam
# Никель_close_finam
# Медь_close_finam
# Цинк_close_finam
# Пшеница_close_finam
# Brent_close_finam

# %% [markdown]
# ## Посмотрим на данные

# %%
df.tail()
# Out:
#                            Gbp/Cad_close_finam  Aud/Cad_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              1.61836              0.89728
# 2019-08-07 14:00:00+00:00              1.62051              0.89792
# 2019-08-07 15:00:00+00:00              1.61695              0.89912
# 2019-08-07 16:00:00+00:00              1.62058              0.90017
# 2019-08-07 17:00:00+00:00              1.62021              0.90123
#
#                            Usd/Cad_close_finam  Eur/Cad_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              1.33371              1.49460
# 2019-08-07 14:00:00+00:00              1.33235              1.49675
# 2019-08-07 15:00:00+00:00              1.33076              1.49251
# 2019-08-07 16:00:00+00:00              1.33309              1.49771
# 2019-08-07 17:00:00+00:00              1.33303              1.49655
#
#                            Cad/Chf_close_finam  Cad/Jpy_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              0.73082                  NaN
# 2019-08-07 14:00:00+00:00              0.72961                  NaN
# 2019-08-07 15:00:00+00:00              0.73139                  NaN
# 2019-08-07 16:00:00+00:00              0.72827                  NaN
# 2019-08-07 17:00:00+00:00              0.72894                  NaN
#
#                            Cad/Usd_close_finam  Nzd/Cad_close_finam  \
# time
# 2019-08-07 13:00:00+00:00               0.7496              0.85728
# 2019-08-07 14:00:00+00:00               0.7503              0.85842
# 2019-08-07 15:00:00+00:00               0.7512              0.85941
# 2019-08-07 16:00:00+00:00               0.7499              0.86129
# 2019-08-07 17:00:00+00:00               0.7500              0.86076
#
#                            Никель_close_finam  Медь_close_finam  \
# time
# 2019-08-07 13:00:00+00:00             14755.0       5626.215760
# 2019-08-07 14:00:00+00:00             14630.0       5617.397240
# 2019-08-07 15:00:00+00:00             14650.0       5653.773635
# 2019-08-07 16:00:00+00:00             14810.0       5660.387525
# 2019-08-07 17:00:00+00:00             15240.0       5669.206045
#
#                            Цинк_close_finam  Пшеница_close_finam  \
# time
# 2019-08-07 13:00:00+00:00            2258.0                482.0
# 2019-08-07 14:00:00+00:00            2250.0                479.4
# 2019-08-07 15:00:00+00:00            2250.0                478.6
# 2019-08-07 16:00:00+00:00            2251.0                485.2
# 2019-08-07 17:00:00+00:00            2251.0                484.0
#
#                            Brent_close_finam
# time
# 2019-08-07 13:00:00+00:00              57.70
# 2019-08-07 14:00:00+00:00              57.00
# 2019-08-07 15:00:00+00:00              56.98
# 2019-08-07 16:00:00+00:00              56.10
# 2019-08-07 17:00:00+00:00              56.41

# %%
df.describe()
# Out:
#        Gbp/Cad_close_finam  Aud/Cad_close_finam  Usd/Cad_close_finam  \
# count         25809.000000         25935.000000         25976.000000
# mean              1.759104             0.973108             1.312206
# std               0.125404             0.027959             0.036856
# min               1.574240             0.890320             1.206650
# 25%               1.675810             0.950360             1.289865
# 50%               1.718630             0.977250             1.313580
# 75%               1.789970             0.994210             1.334000
# max               2.095400             1.036950             1.468480
#
#        Eur/Cad_close_finam  Cad/Chf_close_finam  Cad/Jpy_close_finam  \
# count         26067.000000         25722.000000         25165.000000
# mean              1.487154             0.750575            84.970158
# std               0.043501             0.017212             3.751262
# min               1.376980             0.680680            74.927000
# 25%               1.459110             0.740540            82.494000
# 50%               1.491450             0.752010            84.841000
# 75%               1.513010             0.761330            87.361000
# max               1.614860             0.794410            95.912000
#
#        Cad/Usd_close_finam  Nzd/Cad_close_finam  Никель_close_finam  \
# count         26030.000000         25603.000000        18186.000000
# mean              0.762365             0.906830        11193.392995
# std               0.021421             0.031552         1827.000673
# min               0.681000             0.830390         7580.000000
# 25%               0.749300             0.882985         9805.000000
# 50%               0.761000             0.905200        10935.000000
# 75%               0.775000             0.933295        12610.000000
# max               0.828500             0.990100        16380.000000
#
#        Медь_close_finam  Цинк_close_finam  Пшеница_close_finam  \
# count      23588.000000       3594.000000         18957.000000
# mean        5793.999945       2565.689747           467.706280
# std          790.757476        532.209952            39.907992
# min         4279.186830       1453.000000           389.200000
# 25%         5023.249455       2268.500000           432.600000
# 50%         5885.259785       2627.000000           466.400000
# 75%         6418.780245       2920.000000           502.600000
# max         7306.143820       3619.000000           586.400000
#
#        Brent_close_finam
# count       23184.000000
# mean           57.447940
# std            12.074609
# min            27.400000
# 25%            48.630000
# 50%            55.700000
# 75%            66.892500
# max            86.490000

# %%
df.corr()
# Out:
#                      Gbp/Cad_close_finam  Aud/Cad_close_finam  \
# Gbp/Cad_close_finam             1.000000            -0.108700
# Aud/Cad_close_finam            -0.108700             1.000000
# Usd/Cad_close_finam             0.380836             0.052796
# Eur/Cad_close_finam             0.182748            -0.077473
# Cad/Chf_close_finam            -0.510217            -0.175833
# Cad/Jpy_close_finam             0.318075            -0.229282
# Cad/Usd_close_finam            -0.374824            -0.043028
# Nzd/Cad_close_finam            -0.255487             0.787378
# Никель_close_finam             -0.413726            -0.299226
# Медь_close_finam               -0.516292            -0.041554
# Цинк_close_finam               -0.685902             0.167808
# Пшеница_close_finam             0.241228            -0.566114
# Brent_close_finam              -0.468789            -0.404316
#
#                      Usd/Cad_close_finam  Eur/Cad_close_finam  \
# Gbp/Cad_close_finam             0.380836             0.182748
# Aud/Cad_close_finam             0.052796            -0.077473
# Usd/Cad_close_finam             1.000000             0.043142
# Eur/Cad_close_finam             0.043142             1.000000
# Cad/Chf_close_finam            -0.708822            -0.328853
# Cad/Jpy_close_finam            -0.333590            -0.155543
# Cad/Usd_close_finam            -0.998849            -0.033191
# Nzd/Cad_close_finam             0.226459            -0.111624
# Никель_close_finam             -0.351686             0.438211
# Медь_close_finam               -0.514408             0.394862
# Цинк_close_finam               -0.550574             0.297140
# Пшеница_close_finam             0.038498             0.325179
# Brent_close_finam              -0.358011             0.368683
#
#                      Cad/Chf_close_finam  Cad/Jpy_close_finam  \
# Gbp/Cad_close_finam            -0.510217             0.318075
# Aud/Cad_close_finam            -0.175833            -0.229282
# Usd/Cad_close_finam            -0.708822            -0.333590
# Eur/Cad_close_finam            -0.328853            -0.155543
# Cad/Chf_close_finam             1.000000             0.370755
# Cad/Jpy_close_finam             0.370755             1.000000
# Cad/Usd_close_finam             0.704463             0.338215
# Nzd/Cad_close_finam            -0.273530            -0.526695
# Никель_close_finam              0.395548            -0.006463
# Медь_close_finam                0.519627             0.229314
# Цинк_close_finam                0.517626            -0.010088
# Пшеница_close_finam            -0.079428             0.245610
# Brent_close_finam               0.477527             0.046548
#
#                      Cad/Usd_close_finam  Nzd/Cad_close_finam  \
# Gbp/Cad_close_finam            -0.374824            -0.255487
# Aud/Cad_close_finam            -0.043028             0.787378
# Usd/Cad_close_finam            -0.998849             0.226459
# Eur/Cad_close_finam            -0.033191            -0.111624
# Cad/Chf_close_finam             0.704463            -0.273530
# Cad/Jpy_close_finam             0.338215            -0.526695
# Cad/Usd_close_finam             1.000000            -0.223064
# Nzd/Cad_close_finam            -0.223064             1.000000
# Никель_close_finam              0.343520            -0.235736
# Медь_close_finam                0.515880            -0.109013
# Цинк_close_finam                0.551433             0.158133
# Пшеница_close_finam            -0.045848            -0.547359
# Brent_close_finam               0.344309            -0.349176
#
#                      Никель_close_finam  Медь_close_finam  Цинк_close_finam  \
# Gbp/Cad_close_finam           -0.413726         -0.516292         -0.685902
# Aud/Cad_close_finam           -0.299226         -0.041554          0.167808
# Usd/Cad_close_finam           -0.351686         -0.514408         -0.550574
# Eur/Cad_close_finam            0.438211          0.394862          0.297140
# Cad/Chf_close_finam            0.395548          0.519627          0.517626
# Cad/Jpy_close_finam           -0.006463          0.229314         -0.010088
# Cad/Usd_close_finam            0.343520          0.515880          0.551433
# Nzd/Cad_close_finam           -0.235736         -0.109013          0.158133
# Никель_close_finam             1.000000          0.766660          0.671555
# Медь_close_finam               0.766660          1.000000          0.919344
# Цинк_close_finam               0.671555          0.919344          1.000000
# Пшеница_close_finam            0.264677          0.059146         -0.187387
# Brent_close_finam              0.867561          0.748001          0.655808
#
#                      Пшеница_close_finam  Brent_close_finam
# Gbp/Cad_close_finam             0.241228          -0.468789
# Aud/Cad_close_finam            -0.566114          -0.404316
# Usd/Cad_close_finam             0.038498          -0.358011
# Eur/Cad_close_finam             0.325179           0.368683
# Cad/Chf_close_finam            -0.079428           0.477527
# Cad/Jpy_close_finam             0.245610           0.046548
# Cad/Usd_close_finam            -0.045848           0.344309
# Nzd/Cad_close_finam            -0.547359          -0.349176
# Никель_close_finam              0.264677           0.867561
# Медь_close_finam                0.059146           0.748001
# Цинк_close_finam               -0.187387           0.655808
# Пшеница_close_finam             1.000000           0.324098
# Brent_close_finam               0.324098           1.000000

# %%
# Что-то странное с Cad/Jpy. Нет данных. Дропнем пока.
df['Cad/Jpy_close_finam'].dropna().tail()
# Out:
# time
# 2019-07-09 20:00:00+00:00    82.880
# 2019-07-09 21:00:00+00:00    82.821
# 2019-07-09 22:00:00+00:00    82.929
# 2019-07-09 23:00:00+00:00    82.958
# 2019-07-10 00:00:00+00:00    82.934
# Name: Cad/Jpy_close_finam, dtype: float64

# %%
df = df.drop(['Cad/Jpy_close_finam'], axis=1)

# %%
df.head(10)
# Out:
#                            Gbp/Cad_close_finam  Aud/Cad_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              2.03823              0.97048
# 2015-08-10 13:00:00+00:00              2.03630              0.96897
# 2015-08-10 14:00:00+00:00              2.03605              0.96823
# 2015-08-10 15:00:00+00:00              2.03504              0.96740
# 2015-08-10 16:00:00+00:00              2.03777              0.96718
# 2015-08-10 17:00:00+00:00              2.03605              0.96724
# 2015-08-10 18:00:00+00:00              2.03232              0.96659
# 2015-08-10 19:00:00+00:00              2.02936              0.96648
# 2015-08-10 20:00:00+00:00              2.02951              0.96559
# 2015-08-10 21:00:00+00:00              2.03022              0.96457
#
#                            Usd/Cad_close_finam  Eur/Cad_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              1.31744              1.44446
# 2015-08-10 13:00:00+00:00              1.31685              1.44088
# 2015-08-10 14:00:00+00:00              1.31598              1.43867
# 2015-08-10 15:00:00+00:00              1.31360              1.43983
# 2015-08-10 16:00:00+00:00              1.31386              1.43840
# 2015-08-10 17:00:00+00:00              1.31187              1.43918
# 2015-08-10 18:00:00+00:00              1.30763              1.43564
# 2015-08-10 19:00:00+00:00              1.30554              1.43526
# 2015-08-10 20:00:00+00:00              1.30152              1.43478
# 2015-08-10 21:00:00+00:00              1.30194              1.43511
#
#                            Cad/Chf_close_finam  Cad/Usd_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              0.74533               0.7588
# 2015-08-10 13:00:00+00:00              0.74714               0.7591
# 2015-08-10 14:00:00+00:00              0.74838               0.7596
# 2015-08-10 15:00:00+00:00              0.74924               0.7611
# 2015-08-10 16:00:00+00:00              0.75086               0.7610
# 2015-08-10 17:00:00+00:00              0.75288               0.7620
# 2015-08-10 18:00:00+00:00              0.75422               0.7645
# 2015-08-10 19:00:00+00:00              0.75419               0.7658
# 2015-08-10 20:00:00+00:00              0.75494               0.7683
# 2015-08-10 21:00:00+00:00              0.75482               0.7679
#
#                            Nzd/Cad_close_finam  Никель_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              0.86537             10985.0
# 2015-08-10 13:00:00+00:00              0.86439             10980.0
# 2015-08-10 14:00:00+00:00              0.86325             11085.0
# 2015-08-10 15:00:00+00:00              0.86389             11140.0
# 2015-08-10 16:00:00+00:00              0.86329             11170.0
# 2015-08-10 17:00:00+00:00              0.86336             11170.0
# 2015-08-10 18:00:00+00:00              0.86218             11180.0
# 2015-08-10 19:00:00+00:00              0.86178                 NaN
# 2015-08-10 20:00:00+00:00              0.86152                 NaN
# 2015-08-10 21:00:00+00:00              0.86118                 NaN
#
#                            Медь_close_finam  Цинк_close_finam  \
# time
# 2015-08-10 12:00:00+00:00       5161.038830            1862.5
# 2015-08-10 13:00:00+00:00       5166.550405            1862.5
# 2015-08-10 14:00:00+00:00       5201.824485               NaN
# 2015-08-10 15:00:00+00:00       5247.019400               NaN
# 2015-08-10 16:00:00+00:00       5301.032835               NaN
# 2015-08-10 17:00:00+00:00       5290.009685            1872.0
# 2015-08-10 18:00:00+00:00       5291.112000               NaN
# 2015-08-10 19:00:00+00:00       5284.498110               NaN
# 2015-08-10 20:00:00+00:00       5265.758755               NaN
# 2015-08-10 21:00:00+00:00       5263.554125               NaN
#
#                            Пшеница_close_finam  Brent_close_finam
# time
# 2015-08-10 12:00:00+00:00                512.0              48.96
# 2015-08-10 13:00:00+00:00                511.2              48.94
# 2015-08-10 14:00:00+00:00                513.4              49.13
# 2015-08-10 15:00:00+00:00                520.6              49.85
# 2015-08-10 16:00:00+00:00                525.6              49.88
# 2015-08-10 17:00:00+00:00                522.6              50.18
# 2015-08-10 18:00:00+00:00                524.0              50.13
# 2015-08-10 19:00:00+00:00                523.6              50.25
# 2015-08-10 20:00:00+00:00                  NaN              50.16
# 2015-08-10 21:00:00+00:00                  NaN              50.20

# %%
df.tail()
# Out:
#                            Gbp/Cad_close_finam  Aud/Cad_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              1.61836              0.89728
# 2019-08-07 14:00:00+00:00              1.62051              0.89792
# 2019-08-07 15:00:00+00:00              1.61695              0.89912
# 2019-08-07 16:00:00+00:00              1.62058              0.90017
# 2019-08-07 17:00:00+00:00              1.62021              0.90123
#
#                            Usd/Cad_close_finam  Eur/Cad_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              1.33371              1.49460
# 2019-08-07 14:00:00+00:00              1.33235              1.49675
# 2019-08-07 15:00:00+00:00              1.33076              1.49251
# 2019-08-07 16:00:00+00:00              1.33309              1.49771
# 2019-08-07 17:00:00+00:00              1.33303              1.49655
#
#                            Cad/Chf_close_finam  Cad/Usd_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              0.73082               0.7496
# 2019-08-07 14:00:00+00:00              0.72961               0.7503
# 2019-08-07 15:00:00+00:00              0.73139               0.7512
# 2019-08-07 16:00:00+00:00              0.72827               0.7499
# 2019-08-07 17:00:00+00:00              0.72894               0.7500
#
#                            Nzd/Cad_close_finam  Никель_close_finam  \
# time
# 2019-08-07 13:00:00+00:00              0.85728             14755.0
# 2019-08-07 14:00:00+00:00              0.85842             14630.0
# 2019-08-07 15:00:00+00:00              0.85941             14650.0
# 2019-08-07 16:00:00+00:00              0.86129             14810.0
# 2019-08-07 17:00:00+00:00              0.86076             15240.0
#
#                            Медь_close_finam  Цинк_close_finam  \
# time
# 2019-08-07 13:00:00+00:00       5626.215760            2258.0
# 2019-08-07 14:00:00+00:00       5617.397240            2250.0
# 2019-08-07 15:00:00+00:00       5653.773635            2250.0
# 2019-08-07 16:00:00+00:00       5660.387525            2251.0
# 2019-08-07 17:00:00+00:00       5669.206045            2251.0
#
#                            Пшеница_close_finam  Brent_close_finam
# time
# 2019-08-07 13:00:00+00:00                482.0              57.70
# 2019-08-07 14:00:00+00:00                479.4              57.00
# 2019-08-07 15:00:00+00:00                478.6              56.98
# 2019-08-07 16:00:00+00:00                485.2              56.10
# 2019-08-07 17:00:00+00:00                484.0              56.41

# %%
# Дропнем все до первой полностью заполненной строки
from learning.preprocessing import drop_until_first_full_field
df = drop_until_first_full_field(df)

# %%
df.head()
# Out:
#                            Gbp/Cad_close_finam  Aud/Cad_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              2.03823              0.97048
# 2015-08-10 13:00:00+00:00              2.03630              0.96897
# 2015-08-10 14:00:00+00:00              2.03605              0.96823
# 2015-08-10 15:00:00+00:00              2.03504              0.96740
# 2015-08-10 16:00:00+00:00              2.03777              0.96718
#
#                            Usd/Cad_close_finam  Eur/Cad_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              1.31744              1.44446
# 2015-08-10 13:00:00+00:00              1.31685              1.44088
# 2015-08-10 14:00:00+00:00              1.31598              1.43867
# 2015-08-10 15:00:00+00:00              1.31360              1.43983
# 2015-08-10 16:00:00+00:00              1.31386              1.43840
#
#                            Cad/Chf_close_finam  Cad/Usd_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              0.74533               0.7588
# 2015-08-10 13:00:00+00:00              0.74714               0.7591
# 2015-08-10 14:00:00+00:00              0.74838               0.7596
# 2015-08-10 15:00:00+00:00              0.74924               0.7611
# 2015-08-10 16:00:00+00:00              0.75086               0.7610
#
#                            Nzd/Cad_close_finam  Никель_close_finam  \
# time
# 2015-08-10 12:00:00+00:00              0.86537             10985.0
# 2015-08-10 13:00:00+00:00              0.86439             10980.0
# 2015-08-10 14:00:00+00:00              0.86325             11085.0
# 2015-08-10 15:00:00+00:00              0.86389             11140.0
# 2015-08-10 16:00:00+00:00              0.86329             11170.0
#
#                            Медь_close_finam  Цинк_close_finam  \
# time
# 2015-08-10 12:00:00+00:00       5161.038830            1862.5
# 2015-08-10 13:00:00+00:00       5166.550405            1862.5
# 2015-08-10 14:00:00+00:00       5201.824485               NaN
# 2015-08-10 15:00:00+00:00       5247.019400               NaN
# 2015-08-10 16:00:00+00:00       5301.032835               NaN
#
#                            Пшеница_close_finam  Brent_close_finam
# time
# 2015-08-10 12:00:00+00:00                512.0              48.96
# 2015-08-10 13:00:00+00:00                511.2              48.94
# 2015-08-10 14:00:00+00:00                513.4              49.13
# 2015-08-10 15:00:00+00:00                520.6              49.85
# 2015-08-10 16:00:00+00:00                525.6              49.88

# %%
# заполним пропущенные значения предыдущими
df = df.fillna(method='bfill')

# %% [markdown]
# ## Попробуем в лоб обучить градиентный бустинг

# %%
X_raw = df
Y_raw = df[['Gbp/Cad_close_finam']]

# %%
new_df = df.drop(df.columns, axis=1)
for column in X_raw:
    for i in range(25, 0, -1):
        new_column = '{}_{}'.format(column, i)
        new_df[new_column] = df[column].shift(i-1) - df[column].shift(i)
    new_df[column] = df[column]
new_df = new_df[25:]
# Out:
# Gbp/Cad_close_finam
# Aud/Cad_close_finam
# Usd/Cad_close_finam
# Eur/Cad_close_finam
# Cad/Chf_close_finam
# Cad/Usd_close_finam
# Nzd/Cad_close_finam
# Никель_close_finam
# Медь_close_finam
# Цинк_close_finam
# Пшеница_close_finam
# Brent_close_finam

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from xgboost import XGBClassifier

# %%
scaler = StandardScaler()
X_norm = scaler.fit_transform(new_df)

# %%
X = X_norm[:-1]
Y = Y_raw.diff().apply(lambda x: 1 if x[0] > 0 else 0, axis=1)[25:][1:]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.15, shuffle=False)

# %%
classifier = XGBClassifier()
classifier.fit(X_train, Y_train)
Y_pred = classifier.predict(X_test)

# %%
print (accuracy_score(Y_train, classifier.predict(X_train)))
print (accuracy_score(Y_test, Y_pred))
# Out:
# 0.634701760689903
# 0.5559796437659033

# %% [markdown]
# # TODO
# Градиентный бустинг в лоб дал accuracy 0.63 на обучении и 0.55 на тесте.
# Несмотря на то, что модель явно переобучилась, для попытки обучиться "в лоб" без подбора параметров и регуляризации - получилось неплохо.
#
# - поиграться с параметрами модели. Попробовать grid search;
# - поиграться с глубиной временного окна;
# - добавить регуляризацию;
# - добавить категориальные признаки (время, месяц, сезон, день недели...);
# - попробовать другие модели (в первую очередь LSTM);
# - научиться в обучение с подкреплением;
# - добавить в модель признаки второй страны (пока добавил только CAD);
# - попробовать иначе заполнять NaN. Сначала дропнуть все строки, у которых NaN в таргетной колонке. Потом уже заполнять предыдущими значениями.
